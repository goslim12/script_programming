# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pandas import ExcelWriter

# %%
# %matplotlib inline

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0     1
# 1     3
# 2     5
# 3   NaN
# 4     6
# 5     8
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2013-01-01, ..., 2013-01-06]
# Length: 6, Freq: D, Timezone: None

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.281898  0.222640 -0.471731 -1.221136
# 2013-01-02 -0.026145  0.178425  0.748380 -0.629779
# 2013-01-03 -0.313336 -2.345340 -0.331822 -1.116372
# 2013-01-04  1.910752 -1.078017  1.531613 -0.892602
# 2013-01-05 -0.369121  0.147492 -1.654693 -0.524392
# 2013-01-06 -0.944221 -0.837015 -0.718186  0.674646

# %%
df2 = pd.DataFrame({ 'A' : 1.,'B' : pd.Timestamp('20130102'),'C' : pd.Series(1,index=list(range(4)),dtype='float32'),'D' : np.array([3] * 4,dtype='int32'),'E' : pd.Categorical(["test","train","test","train"]),'F' : 'foo'})

# %%
df2
# Out:
#    A          B  C  D      E    F
# 0  1 2013-01-02  1  3   test  foo
# 1  1 2013-01-02  1  3  train  foo
# 2  1 2013-01-02  1  3   test  foo
# 3  1 2013-01-02  1  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
# df2.<TAB> 과 같이  <TAB>누르면 그에 관련된 함수목록을 출력할 수 있다.

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.281898  0.222640 -0.471731 -1.221136
# 2013-01-02 -0.026145  0.178425  0.748380 -0.629779
# 2013-01-03 -0.313336 -2.345340 -0.331822 -1.116372
# 2013-01-04  1.910752 -1.078017  1.531613 -0.892602
# 2013-01-05 -0.369121  0.147492 -1.654693 -0.524392

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  1.910752 -1.078017  1.531613 -0.892602
# 2013-01-05 -0.369121  0.147492 -1.654693 -0.524392
# 2013-01-06 -0.944221 -0.837015 -0.718186  0.674646

# %%
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2013-01-01, ..., 2013-01-06]
# Length: 6, Freq: D, Timezone: None

# %%
df.columns
# Out:
# Index([u'A', u'B', u'C', u'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.28189771,  0.22263956, -0.47173121, -1.22113613],
#        [-0.0261453 ,  0.17842544,  0.74837975, -0.629779  ],
#        [-0.31333641, -2.34533963, -0.33182182, -1.11637203],
#        [ 1.91075166, -1.07801716,  1.53161337, -0.89260156],
#        [-0.36912085,  0.14749169, -1.65469299, -0.52439229],
#        [-0.94422065, -0.83701471, -0.71818604,  0.67464631]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.089971 -0.618636 -0.149406 -0.618272
# std    0.980667  1.016880  1.127689  0.688097
# min   -0.944221 -2.345340 -1.654693 -1.221136
# 25%   -0.355175 -1.017767 -0.656572 -1.060429
# 50%   -0.169741 -0.344762 -0.401777 -0.761190
# 75%    0.204887  0.170692  0.478329 -0.550739
# max    1.910752  0.222640  1.531613  0.674646

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.281898   -0.026145   -0.313336    1.910752   -0.369121   -0.944221
# B    0.222640    0.178425   -2.345340   -1.078017    0.147492   -0.837015
# C   -0.471731    0.748380   -0.331822    1.531613   -1.654693   -0.718186
# D   -1.221136   -0.629779   -1.116372   -0.892602   -0.524392    0.674646

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.221136 -0.471731  0.222640  0.281898
# 2013-01-02 -0.629779  0.748380  0.178425 -0.026145
# 2013-01-03 -1.116372 -0.331822 -2.345340 -0.313336
# 2013-01-04 -0.892602  1.531613 -1.078017  1.910752
# 2013-01-05 -0.524392 -1.654693  0.147492 -0.369121
# 2013-01-06  0.674646 -0.718186 -0.837015 -0.944221

# %%
df.sort(columns='B')
# Out:
#                    A         B         C         D
# 2013-01-03 -0.313336 -2.345340 -0.331822 -1.116372
# 2013-01-04  1.910752 -1.078017  1.531613 -0.892602
# 2013-01-06 -0.944221 -0.837015 -0.718186  0.674646
# 2013-01-05 -0.369121  0.147492 -1.654693 -0.524392
# 2013-01-02 -0.026145  0.178425  0.748380 -0.629779
# 2013-01-01  0.281898  0.222640 -0.471731 -1.221136

# %%
df['A']
# Out:
# 2013-01-01    0.281898
# 2013-01-02   -0.026145
# 2013-01-03   -0.313336
# 2013-01-04    1.910752
# 2013-01-05   -0.369121
# 2013-01-06   -0.944221
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.281898  0.222640 -0.471731 -1.221136
# 2013-01-02 -0.026145  0.178425  0.748380 -0.629779
# 2013-01-03 -0.313336 -2.345340 -0.331822 -1.116372

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.026145  0.178425  0.748380 -0.629779
# 2013-01-03 -0.313336 -2.345340 -0.331822 -1.116372
# 2013-01-04  1.910752 -1.078017  1.531613 -0.892602

# %%
df.loc[dates[0]]
# Out:
# A    0.281898
# B    0.222640
# C   -0.471731
# D   -1.221136
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01  0.281898  0.222640
# 2013-01-02 -0.026145  0.178425
# 2013-01-03 -0.313336 -2.345340
# 2013-01-04  1.910752 -1.078017
# 2013-01-05 -0.369121  0.147492
# 2013-01-06 -0.944221 -0.837015

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02 -0.026145  0.178425
# 2013-01-03 -0.313336 -2.345340
# 2013-01-04  1.910752 -1.078017

# %%
df.loc['20130102',['A','B']]
# Out:
# A   -0.026145
# B    0.178425
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0],'A']
# Out:
# 0.28189770777564127

# %%
df.at[dates[0],'A']
# Out:
# 0.28189770777564127

# %%
df.iloc[3]
# Out:
# A    1.910752
# B   -1.078017
# C    1.531613
# D   -0.892602
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04  1.910752 -1.078017
# 2013-01-05 -0.369121  0.147492

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.026145  0.748380
# 2013-01-03 -0.313336 -0.331822
# 2013-01-05 -0.369121 -1.654693

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.026145  0.178425  0.748380 -0.629779
# 2013-01-03 -0.313336 -2.345340 -0.331822 -1.116372

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01  0.222640 -0.471731
# 2013-01-02  0.178425  0.748380
# 2013-01-03 -2.345340 -0.331822
# 2013-01-04 -1.078017  1.531613
# 2013-01-05  0.147492 -1.654693
# 2013-01-06 -0.837015 -0.718186

# %%
df.iloc[1,1]
# Out:
# 0.1784254369687592

# %%
df.iat[1,1]
# Out:
# 0.1784254369687592

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.281898  0.222640 -0.471731 -1.221136
# 2013-01-04  1.910752 -1.078017  1.531613 -0.892602

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.281898  0.222640       NaN       NaN
# 2013-01-02       NaN  0.178425  0.748380       NaN
# 2013-01-03       NaN       NaN       NaN       NaN
# 2013-01-04  1.910752       NaN  1.531613       NaN
# 2013-01-05       NaN  0.147492       NaN       NaN
# 2013-01-06       NaN       NaN       NaN  0.674646

# %%
df2 = df.copy()

# %%
df2['E'] = ['one', 'one','two','three','four','three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.281898  0.222640 -0.471731 -1.221136    one
# 2013-01-02 -0.026145  0.178425  0.748380 -0.629779    one
# 2013-01-03 -0.313336 -2.345340 -0.331822 -1.116372    two
# 2013-01-04  1.910752 -1.078017  1.531613 -0.892602  three
# 2013-01-05 -0.369121  0.147492 -1.654693 -0.524392   four
# 2013-01-06 -0.944221 -0.837015 -0.718186  0.674646  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.313336 -2.345340 -0.331822 -1.116372   two
# 2013-01-05 -0.369121  0.147492 -1.654693 -0.524392  four

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
df.at[dates[0],'A'] = 0

# %%
df.iat[0,1] = 0

# %%
df.loc[:,'D'] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D   F
# 2013-01-01  0.000000  0.000000 -0.471731  5 NaN
# 2013-01-02 -0.026145  0.178425  0.748380  5   1
# 2013-01-03 -0.313336 -2.345340 -0.331822  5   2
# 2013-01-04  1.910752 -1.078017  1.531613  5   3
# 2013-01-05 -0.369121  0.147492 -1.654693  5   4
# 2013-01-06 -0.944221 -0.837015 -0.718186  5   5

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D   F
# 2013-01-01  0.000000  0.000000 -0.471731 -5 NaN
# 2013-01-02 -0.026145 -0.178425 -0.748380 -5  -1
# 2013-01-03 -0.313336 -2.345340 -0.331822 -5  -2
# 2013-01-04 -1.910752 -1.078017 -1.531613 -5  -3
# 2013-01-05 -0.369121 -0.147492 -1.654693 -5  -4
# 2013-01-06 -0.944221 -0.837015 -0.718186 -5  -5

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                    A         B         C  D   F   E
# 2013-01-01  0.000000  0.000000 -0.471731  5 NaN   1
# 2013-01-02 -0.026145  0.178425  0.748380  5   1   1
# 2013-01-03 -0.313336 -2.345340 -0.331822  5   2 NaN
# 2013-01-04  1.910752 -1.078017  1.531613  5   3 NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B        C  D  F  E
# 2013-01-02 -0.026145  0.178425  0.74838  5  1  1

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D  F  E
# 2013-01-01  0.000000  0.000000 -0.471731  5  5  1
# 2013-01-02 -0.026145  0.178425  0.748380  5  1  1
# 2013-01-03 -0.313336 -2.345340 -0.331822  5  2  5
# 2013-01-04  1.910752 -1.078017  1.531613  5  3  5

# %%
pd.isnull(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A    0.042988
# B   -0.655742
# C   -0.149406
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.132067
# 2013-01-02    1.380132
# 2013-01-03    0.801900
# 2013-01-04    2.072870
# 2013-01-05    1.424736
# 2013-01-06    1.500116
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01   NaN
# 2013-01-02   NaN
# 2013-01-03     1
# 2013-01-04     3
# 2013-01-05     5
# 2013-01-06   NaN
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C  D   F
# 2013-01-01  0.000000  0.000000 -0.471731  5 NaN
# 2013-01-02 -0.026145  0.178425  0.748380  5   1
# 2013-01-03 -0.313336 -2.345340 -0.331822  5   2
# 2013-01-04  1.910752 -1.078017  1.531613  5   3
# 2013-01-05 -0.369121  0.147492 -1.654693  5   4
# 2013-01-06 -0.944221 -0.837015 -0.718186  5   5

# %%
#Series 객체 s의 값들을 DataFraeme 객체 df 값들에 뺄셈 적용
df.sub(s, axis='index')
# Out:
#                    A         B         C   D   F
# 2013-01-01       NaN       NaN       NaN NaN NaN
# 2013-01-02       NaN       NaN       NaN NaN NaN
# 2013-01-03 -1.313336 -3.345340 -1.331822   4   1
# 2013-01-04 -1.089248 -4.078017 -1.468387   2   0
# 2013-01-05 -5.369121 -4.852508 -6.654693   0  -1
# 2013-01-06       NaN       NaN       NaN NaN NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D   F
# 2013-01-01  0.000000  0.000000 -0.471731   5 NaN
# 2013-01-02 -0.026145  0.178425  0.276649  10   1
# 2013-01-03 -0.339482 -2.166914 -0.055173  15   3
# 2013-01-04  1.571270 -3.244931  1.476440  20   6
# 2013-01-05  1.202149 -3.097440 -0.178253  25  10
# 2013-01-06  0.257928 -3.934454 -0.896439  30  15

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.854972
# B    2.523765
# C    3.186306
# D    0.000000
# F    4.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    1
# 1    4
# 2    6
# 3    0
# 4    4
# 5    4
# 6    2
# 7    6
# 8    2
# 9    0
# dtype: int32

# %%
s.value_counts()
# Out:
# 4    3
# 6    2
# 2    2
# 0    2
# 1    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.854781 -0.374782  1.590109 -0.487570
# 1 -1.775724  0.220558 -1.265898 -0.416354
# 2  1.527103 -2.233545  0.464814 -0.925343
# 3  0.961825 -0.638090 -0.178475  0.562922
# 4 -0.077115  1.499715 -0.388981 -0.409909
# 5 -0.021026 -0.685470 -0.385116 -0.297621
# 6  0.296249 -0.673464 -0.046462  1.039822
# 7  0.526083 -0.401028 -0.737144 -0.440787
# 8  0.354878  0.956269  0.194421  0.462912
# 9 -1.350114  2.201098 -0.377859 -0.590955

# %%
pd.concat?

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.854781 -0.374782  1.590109 -0.487570
# 1 -1.775724  0.220558 -1.265898 -0.416354
# 2  1.527103 -2.233545  0.464814 -0.925343
# 3  0.961825 -0.638090 -0.178475  0.562922
# 4 -0.077115  1.499715 -0.388981 -0.409909
# 5 -0.021026 -0.685470 -0.385116 -0.297621
# 6  0.296249 -0.673464 -0.046462  1.039822
# 7  0.526083 -0.401028 -0.737144 -0.440787
# 8  0.354878  0.956269  0.194421  0.462912
# 9 -1.350114  2.201098 -0.377859 -0.590955

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0 -1.687083 -0.711474 -0.722038  0.765039
# 1  1.901968 -1.780491  0.711013  0.448457
# 2 -0.799548 -0.144792  0.195960  0.667154
# 3  0.126465  0.073497 -0.704421 -0.694478
# 4 -0.336219 -0.832431 -0.895438 -0.561938
# 5  0.491715  1.346468  0.759970 -1.089768
# 6 -0.883777  1.899816  0.496336  0.862655
# 7 -1.770062 -0.800945 -1.114518 -0.517820

# %%
s = df.iloc[3]

# %%
 df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -1.687083 -0.711474 -0.722038  0.765039
# 1  1.901968 -1.780491  0.711013  0.448457
# 2 -0.799548 -0.144792  0.195960  0.667154
# 3  0.126465  0.073497 -0.704421 -0.694478
# 4 -0.336219 -0.832431 -0.895438 -0.561938
# 5  0.491715  1.346468  0.759970 -1.089768
# 6 -0.883777  1.899816  0.496336  0.862655
# 7 -1.770062 -0.800945 -1.114518 -0.517820
# 8  0.126465  0.073497 -0.704421 -0.694478

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar','foo', 'bar', 'foo', 'foo'],'B' : ['one', 'one', 'two', 'three','two', 'two', 'one', 'three'],'C' : np.random.randn(8),'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.980426  0.938795
# 1  bar    one -0.228082  2.347521
# 2  foo    two  0.737420  0.802841
# 3  bar  three  0.626023 -0.417446
# 4  foo    two -0.230060  1.191593
# 5  bar    two  0.793651  0.272018
# 6  foo    one -1.456935 -1.330561
# 7  foo  three -0.956616  0.292840

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  1.191592  2.202093
# foo -2.886618  1.895508

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.228082  2.347521
#     three  0.626023 -0.417446
#     two    0.793651  0.272018
# foo one   -2.437361 -0.391766
#     three -0.956616  0.292840
#     two    0.507360  1.994434

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz','foo', 'foo', 'qux', 'qux'],['one', 'two', 'one', 'two','one', 'two', 'one', 'two']]))

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.272092 -0.711796
#       two    -1.134708  0.751141
# baz   one     0.528637 -0.200166
#       two    -1.492465 -1.216267

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.272092
#                B   -0.711796
#        two     A   -1.134708
#                B    0.751141
# baz    one     A    0.528637
#                B   -0.200166
#        two     A   -1.492465
#                B   -1.216267
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.272092 -0.711796
#       two    -1.134708  0.751141
# baz   one     0.528637 -0.200166
#       two    -1.492465 -1.216267

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.272092  0.528637
#        B -0.711796 -0.200166
# two    A -1.134708 -1.492465
#        B  0.751141 -1.216267

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,'B' : ['A', 'B', 'C'] * 4,'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2, 'D' : np.random.randn(12),'E' : np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.828092  0.772501
# 1     one  B  foo  0.221054  0.269274
# 2     two  C  foo -1.573707 -0.903514
# 3   three  A  bar  0.210818 -0.173897
# 4     one  B  bar -0.538679 -0.538419
# 5     one  C  bar  0.186362 -0.782388
# 6     two  A  foo -0.175116 -1.457289
# 7   three  B  foo -0.897213  0.080112
# 8     one  C  foo -1.299473  0.823576
# 9     one  A  bar -0.259041 -0.415906
# 10    two  B  bar  0.835093 -0.742834
# 11  three  C  bar -1.567391 -0.393168

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.259041  0.828092
#       B -0.538679  0.221054
#       C  0.186362 -1.299473
# three A  0.210818       NaN
#       B       NaN -0.897213
#       C -1.567391       NaN
# two   A       NaN -0.175116
#       B  0.835093       NaN
#       C       NaN -1.573707

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample('5Min', how='sum')
# Out:
# 2012-01-01    26303
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    0.344486
# 2012-03-07   -0.200436
# 2012-03-08    0.805161
# 2012-03-09    0.263796
# 2012-03-10   -0.135824
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.344486
# 2012-03-07 00:00:00+00:00   -0.200436
# 2012-03-08 00:00:00+00:00    0.805161
# 2012-03-09 00:00:00+00:00    0.263796
# 2012-03-10 00:00:00+00:00   -0.135824
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    0.344486
# 2012-03-06 19:00:00-05:00   -0.200436
# 2012-03-07 19:00:00-05:00    0.805161
# 2012-03-08 19:00:00-05:00    0.263796
# 2012-03-09 19:00:00-05:00   -0.135824
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-31   -1.514446
# 2012-02-29    0.405035
# 2012-03-31    0.418212
# 2012-04-30    0.117715
# 2012-05-31    0.574820
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-
# 2000-01-22  5.992528  -0.505263  -7.965873  -9.385365
# 2000-01-23  5.826076  -2.083158  -7.824008  -8.720590
# 2000-01-24  6.090966  -2.802976  -7.272290  -9.591640
# 2000-01-25  6.913726  -2.813472  -8.902645 -10.004385
# 2000-01-26  6.108135  -3.320953 -10.102807 -10.400615
# 2000-01-27  7.413868  -4.799946  -9.628370  -9.500400
# 2000-01-28  6.355087  -4.984425  -9.765858  -8.192062
# 2000-01-29  6.936368  -4.501119  -9.439193  -8.026339
# 2000-01-30  7.173630  -3.626972  -8.733531  -7.756772
# ...              ...        ...        ...        ...
# 2002-08-28 -1.549105  29.250412 -15.898097 -11.558869
# 2002-08-29 -0.767048  30.421752 -16.409870 -12.389327
# 2002-08-30  0.076930  33.002339 -18.277715 -12.688124
# 2002-08-31 -0.949316  31.337747 -19.382257 -11.663347
# 2002-09-01 -1.195417  31.445167 -16.781624 -10.028150
# 2002-09-02 -1.803549  30.453478 -16.588371  -9.407184
# 2002-09-03 -2.396340  31.280382 -15.691994  -8.411814
# 2002-09-04 -0.128371  32.025936 -15.878183  -8.779015
# 2002-09-05  0.543091  31.823869 -16.686449  -7.967020
# 2002-09-06 -0.121853  32.165875 -16.657296  -8.889054
# 2002-09-07  0.377770  32.848630 -14.508707  -9.391215
# 2002-09-08  2.090666  35.078596 -14.778657  -7.811598
# 2002-09-09  0.657717  33.784921 -14.359925  -7.719157
# 2002-09-10  1.936690  34.190337 -13.406510  -7.624693
# 2002-09-11  1.096964  34.244354 -14.191612  -7.462712
# 2002-09-12  1.590350  34.706726 -15.196092  -8.410989
# 2002-09-13  0.402453  33.645540 -14.897863  -8.628873
# 2002-09-14 -2.455593  34.654898 -14.171824  -7.819976
# 2002-09-15 -3.352689  34.137263 -15.601700  -6.565198
# 2002-09-16 -3.485380  33.570840 -14.140633  -7.741857
# 2002-09-17 -3.292083  33.368851 -16.041348  -8.520027
# 2002-09-18 -3.659603  32.132346 -17.522244  -9.926343
# 2002-09-19 -2.734062  32.676368 -18.815849 -10.826237
# 2002-09-20 -0.815600  33.400364 -18.151555 -10.094130
# 2002-09-21 -2.752865  35.541143 -19.265083 -10.319267
# 2002-09-22 -4.133017  35.639399 -21.344054 -10.467125
# 2002-09-23 -3.732545  33.870993 -21.998073  -9.005531
# 2002-09-24 -4.124143  33.308987 -22.807010  -8.220990
# 2002-09-25 -4.880328  32.835695 -22.772707  -6.347889
# 2002-09-26 -5.315385  31.534419 -23.771476  -7.700609
#
# [1000 rows x 4 columns]

# %%
#writer = pd.ExcelWriter('simple.xlsx', engine='xlsxwriter')
#df.to_excel(writer, sheet_name='Sheet1')

# %%
# writer = pd.ExcelWriter('foo.xlsx')

# %%
#df.to_excel(writer,'Sheet1')

# %%
#df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %%
#pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])

# %%
#writer = ExcelWriter('output.xlsx')
#df1.to_excel(writer, 'sheet1')
#df2.to_excel(writer, 'sheet2')
#writer.save()
