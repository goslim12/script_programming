# %% [markdown]
# 웹 URL로 지정된 웹페이지를 문자열로 가져와 1) 모든 HTML 태그를 제외한 순수 텍스트 문자열만을 걸러내고, 2) 그 순수 텍스트 문자열 안에 존재하는 단어가 총 몇개인지 출력하는 프로그램을 작성하시오.

# %%
import urllib2

source = urllib2.urlopen("http://cse.kut.ac.kr/").read()

print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- META -->
# <meta charset="utf-8">
# <meta name="Generator" content="XpressEngine">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <!-- TITLE -->
# <title>컴퓨터공학부</title>
# <!-- CSS -->
# <link rel="stylesheet" href="/common/css/xe.min.css?20150910092654" />
# <link rel="stylesheet" href="/layouts/cse/style/prettyPhoto.css?20150805222706" />
# <link rel="stylesheet" href="/layouts/cse/style/stylemobile.css?20150805222706" />
# <link rel="stylesheet" href="/layouts/cse/style/mobilenavigation.css?20150805222706" />
# <link rel="stylesheet" href="/modules/editor/styles/ckeditor_light/style.css?20150910092713" />
# <link rel="stylesheet" href="/widgets/login_info/skins/cse_login_info_2015/default.login.css?20150420232234" />
# <link rel="stylesheet" href="/widgets/content_cse/skins/cse_latest_2015/css/widget.css?20150625005943" />
# <link rel="stylesheet" href="/addons/font_nanum_gothic/font-nanum_gothic.css?20150429141819" />
# ...

# %%
for i in range(0,source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:1]," ",1)

# %%
for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:1]," ",1)

# %%
for i in range(0,source.count('\n')):
    if source.find("\n") != -1:
        source = source.replace(source[source.find('\n')]," ",1)

# %%
for i in range(0,source.count('\t')):
    if source.find("\t") != -1:
        source = source.replace(source[source.find('\t')]," ",1)

# %%
num = source.split()

# %%
len(num)
# Out:
# 447

# %%
example = """<p class="tit">네이버 앱을 설치하세요!</p>
<fieldset>
<legend>다운로드URL 문자받기</legend>
<span class="txtsm">다운로드URL 문자받기</span>
<label class="blind" for="app_phone">휴대폰번호 입력</label>"""

# %%
for i in range(0,str.count('<!--')):
    if example.find("<!--") != -1:
        example = example.replace(example[example.find("<!--"):example.find("-->")+3:1]," ",1)
for i in range(0,example.count("<")):
    if example.find("<") != -1:
        example = example.replace(example[example.find("<"):example.find(">")+1:1]," ",1)
for i in range(0,source.count('\n')):
    if example.find("\n") != -1:
        example = example.replace(example[example.find('\n')]," ",1)
for i in range(0,source.count('\t')):
    if example.find("\t") != -1:
        example = example.replace(example[example.find('\t')]," ",1)

# %%
example
# Out:
# ' \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xec\x95\xb1\xec\x9d\x84 \xec\x84\xa4\xec\xb9\x98\xed\x95\x98\xec\x84\xb8\xec\x9a\x94! \n \n \xeb\x8b\xa4\xec\x9a\xb4\xeb\xa1\x9c\xeb\x93\x9cURL \xeb\xac\xb8\xec\x9e\x90\xeb\xb0\x9b\xea\xb8\xb0 \n \xeb\x8b\xa4\xec\x9a\xb4\xeb\xa1\x9c\xeb\x93\x9cURL \xeb\xac\xb8\xec\x9e\x90\xeb\xb0\x9b\xea\xb8\xb0 \n \xed\x9c\xb4\xeb\x8c\x80\xed\x8f\xb0\xeb\xb2\x88\xed\x98\xb8 \xec\x9e\x85\xeb\xa0\xa5 '

# %%
example.split()
# Out:
# ['\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84',
#  '\xec\x95\xb1\xec\x9d\x84',
#  '\xec\x84\xa4\xec\xb9\x98\xed\x95\x98\xec\x84\xb8\xec\x9a\x94!',
#  '\xeb\x8b\xa4\xec\x9a\xb4\xeb\xa1\x9c\xeb\x93\x9cURL',
#  '\xeb\xac\xb8\xec\x9e\x90\xeb\xb0\x9b\xea\xb8\xb0',
#  '\xeb\x8b\xa4\xec\x9a\xb4\xeb\xa1\x9c\xeb\x93\x9cURL',
#  '\xeb\xac\xb8\xec\x9e\x90\xeb\xb0\x9b\xea\xb8\xb0',
#  '\xed\x9c\xb4\xeb\x8c\x80\xed\x8f\xb0\xeb\xb2\x88\xed\x98\xb8',
#  '\xec\x9e\x85\xeb\xa0\xa5']

# %%
len(example.split())
# Out:
# 9
