# %% [markdown]
# #### - 다음 코드를 보고 물음에 답하시오.
#
#
#     a = [1, 2, 3]
#     b = a * 3
#     c = [a] * 3
#     print b
#     print c

# %% [markdown]
#  ----------------------------------

# %% [markdown]
# - 1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오.
#
#     a[0]=0

# %%
a = [1, 2, 3]
b = a * 3
c = [a] * 3
print b
print c
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
a[0]=0

# %%
print b
print c
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %% [markdown]
# - 2) b와 c 객체의 차이는 무엇인가?

# %%
a[0] = 1

# %%
a
# Out:
# [1, 2, 3]

# %%
c[0]
# Out:
# [1, 2, 3]

# %%
b[0:3]
# Out:
# [1, 2, 3]

# %%
a is c[0]
# Out:
# True

# %%
a is b[0:3]
# Out:
# False

# %%
a = [1, 2, 3]
b = a * 3
c = [a] * 3
print b
print c
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
a[0] is b[0]
# Out:
# True

# %%
id(a[0])
# Out:
# 34231368

# %%
id(b[0])
# Out:
# 34231368

# %%
a[0] is b[3]
# Out:
# True
